# %% [markdown]
# ### Playing Cards

# %%
import random

suits= ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks= ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10, 'Queen':10,
          'King':10, 'Ace':11}

playing = True

# %%
class Card():
    
    def __init__(self, suit, rank):
        
        self.suit = suit
        self.rank = rank
        
    
    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %%
class Deck():
    
    # Can store 52 Card object in a list
    # Can suffle
    # Add 
    
    # List to hold 52 card objects. 
    
    temp = []
    
    def __init__(self):
        
        self.deck = []
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
                    
    def __len__(self):
        return len(self.deck)
    
    def __str__(self):
        deck_comp = ' '
        self.i = 0
        for card in self.deck:
            self.i += 1 
            deck_comp += '\n' + str(self.i) + ". " + card.__str__() #
        return 'The deck has : ' + deck_comp
        
    def deckshuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card = self.deck.pop()
        return single_card
    
    
    #def deal(self):
    #    self.temp.append(self.cardlist.pop())
    #    self.temp.append(self.cardlist.pop())
    #    return self.temp

# %%
class Hand():
    
    def __init__(self):
        
        self.cards  = []
        self.value = 0
        self.aces = 0
        
    def add_card(self, card):
        self.cards.append(card)
        self.value += values[card.rank]
        if card.rank == 'Ace':
            self.aces+=1
        
    def adjust_for_ace(self):
        ace_count = self.aces
        while self.value > 21 and ace_count > 0:
            self.value -= 10
            ace_count -= 1
            
    def __str__(self):
        hands = ' '
        for i in self.cards:
            hands += '\n' + i.__str__() 
        return hands + ' Values: ' + str(self.value) + 'Aces: ' + str(self.aces)

# %%
class Chips():
    
    def __init__(self):
        self.total = 100
        self.bet = 10
    
    def win_bet(self):
        self.total +=self.bet
    
    def lose_bet(self):
        self.total -=self.bet
    
        
    def __str__(self):
        return 'Total: '+ str(self.total) + '\n' + 'Bet: ' + str(self.bet)

# %%
def take_bet(chips):
    
    while True:
        try:
            chips.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, a bet must be an integer!')
        else:
            if chips.bet > chips.total:
                print("Sorry, your bet cannot exceed", chips.total)
            else:
                break

# %%
def hit(deck, hand):
    hand.add_card(deck.deal())
    hand.adjust_for_ace()

# %%
def hit_or_stand(deck, hand):
    global playing
    
    while True:
        x = input("Would you like to Hit or Stand? Enter 'h' or 's' ")
        
        if x[0].lower() == 'h':
            hit(deck, hand)
        elif x[0].lower() == 's':
                print("Player stands. Dealer is playing.")
                playing = False
        else:
            print("Sorry, please try again.")
            continue
        break

# %%
def show_some(player, dealer):
    print("\nDealer's Hand:")
    print(" <card hidden>")
    print(" ",dealer.cards[1])
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    
def show_all(player, dealer):
    print("\nDealer's Hand:", *dealer.cards, sep='\n ')
    print("Dealer's Hand = ", dealer.value)
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    print("Player's Hand =", player.value)

# %%
def player_busts(player, dealer, chips):
    print("Player busts!")
    chips.lose_bet()

def player_wins(player, dealer, chips):
    print("Player wins!")
    chips.win_bet()
    
def dealer_busts(player, dealer, chips):
    print("Delaer busts!")
    chips.win_bet()

def dealer_wins(player, dealer, chips):
    print("Dealer wins!")
    chips.lose_bet()
    
def push(player, dealer):
    print("Dealer and player tie. It's a push.")

# %% [markdown]
#     ## Now Play The Game!!!

# %%
while True:
    
    print("Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.")
    
    # Create and suffle the deck.
    # Deal two cards to each player. 
    deck = Deck()
    deck.deckshuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
    
    # Set up the player's chips
    player_chips = Chips()
    
    # Prompt the player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep dealer's one card hidden)
    show_some(player_hand, dealer_hand)
    
    while playing:
        
        # Prompt for player to Hit or Stand
        hit_or_stand(deck, player_hand)
        
        # Show cards (but keep delaer's one card hidden)
        show_some(player_hand, dealer_hand)
        
        # If player's hand exceeds 21, run player_bust() and break out of the loop
        
        if player_hand.value > 21:
            player_busts(player_hand, dealer_hand, player_chips)
            break
            
    # if player hasn't busted, play Dealer's hand until Dealer reaches 17
    
    if player_hand.value <= 21:
        
        while dealer_hand.value < 17:
            hit(deck,dealer_hand)
            
        # Show all cards
        show_all(player_hand, dealer_hand)
        
        # Run different winning scenarios 
        if dealer_hand.value > 21:
            dealer_busts(player_hand, dealer_hand, player_chips)
        
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand, dealer_hand, player_chips)
        
        else:
            push(player_hand, dealer_hand)
            
    # Inform players of their chips total
    print("\nPlayer's winning stand at", player_chips.total)
    
    # Ask for play again
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    
    if new_game[0].lower() == 'y':
        playing = True
        continue
    else:
        print("Thank you for playing!")
        break
# Out:
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 10
#
# Dealer's Hand:
#  <card hidden>
#   Seven of Hearts
#
# Player's Hand:
#  Queen of Clubs
#  Five of Diamonds
#
# Dealer's Hand:
#  Three of Clubs
#  Seven of Hearts
#  Four of Clubs
#  Jack of Clubs
# Dealer's Hand =  24
#
# Player's Hand:
#  Queen of Clubs
#  Five of Diamonds
# Player's Hand = 15
# Delaer busts!
#
# Player's winning stand at 110
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 20
#
# Dealer's Hand:
#  <card hidden>
#   Five of Clubs
#
# Player's Hand:
#  Four of Clubs
#  Four of Hearts
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   Five of Clubs
#
# Player's Hand:
#  Four of Clubs
#  Four of Hearts
#  Two of Spades
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   Five of Clubs
#
# Player's Hand:
#  Four of Clubs
#  Four of Hearts
#  Two of Spades
#  King of Clubs
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   Five of Clubs
#
# Player's Hand:
#  Four of Clubs
#  Four of Hearts
#  Two of Spades
#  King of Clubs
#
# Dealer's Hand:
#  Jack of Clubs
#  Five of Clubs
#  Ten of Diamonds
# Dealer's Hand =  25
#
# Player's Hand:
#  Four of Clubs
#  Four of Hearts
#  Two of Spades
#  King of Clubs
# Player's Hand = 20
# Delaer busts!
#
# Player's winning stand at 120
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 30
#
# Dealer's Hand:
#  <card hidden>
#   Five of Spades
#
# Player's Hand:
#  Five of Diamonds
#  Nine of Hearts
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   Five of Spades
#
# Player's Hand:
#  Five of Diamonds
#  Nine of Hearts
#  Four of Hearts
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   Five of Spades
#
# Player's Hand:
#  Five of Diamonds
#  Nine of Hearts
#  Four of Hearts
#
# Dealer's Hand:
#  Nine of Spades
#  Five of Spades
#  Two of Clubs
#  Eight of Spades
# Dealer's Hand =  24
#
# Player's Hand:
#  Five of Diamonds
#  Nine of Hearts
#  Four of Hearts
# Player's Hand = 18
# Delaer busts!
#
# Player's winning stand at 130
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 40
#
# Dealer's Hand:
#  <card hidden>
#   Four of Clubs
#
# Player's Hand:
#  Eight of Hearts
#  Nine of Diamonds
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   Four of Clubs
#
# Player's Hand:
#  Eight of Hearts
#  Nine of Diamonds
#
# Dealer's Hand:
#  Three of Diamonds
#  Four of Clubs
#  Four of Hearts
#  Ten of Hearts
# Dealer's Hand =  21
#
# Player's Hand:
#  Eight of Hearts
#  Nine of Diamonds
# Player's Hand = 17
# Dealer wins!
#
# Player's winning stand at 60
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 40
#
# Dealer's Hand:
#  <card hidden>
#   Ten of Hearts
#
# Player's Hand:
#  Three of Hearts
#  Five of Spades
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   Ten of Hearts
#
# Player's Hand:
#  Three of Hearts
#  Five of Spades
#  Five of Clubs
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   Ten of Hearts
#
# Player's Hand:
#  Three of Hearts
#  Five of Spades
#  Five of Clubs
#  Six of Spades
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   Ten of Hearts
#
# Player's Hand:
#  Three of Hearts
#  Five of Spades
#  Five of Clubs
#  Six of Spades
#
# Dealer's Hand:
#  Ace of Hearts
#  Ten of Hearts
# Dealer's Hand =  21
#
# Player's Hand:
#  Three of Hearts
#  Five of Spades
#  Five of Clubs
#  Six of Spades
# Player's Hand = 19
# Dealer wins!
#
# Player's winning stand at 60
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 60
#
# Dealer's Hand:
#  <card hidden>
#   King of Spades
#
# Player's Hand:
#  Two of Spades
#  Three of Hearts
# Would you like to Hit or Stand? Enter 'h' or 's' h
#
# Dealer's Hand:
#  <card hidden>
#   King of Spades
#
# Player's Hand:
#  Two of Spades
#  Three of Hearts
#  Queen of Spades
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   King of Spades
#
# Player's Hand:
#  Two of Spades
#  Three of Hearts
#  Queen of Spades
#
# Dealer's Hand:
#  Seven of Diamonds
#  King of Spades
# Dealer's Hand =  17
#
# Player's Hand:
#  Two of Spades
#  Three of Hearts
#  Queen of Spades
# Player's Hand = 15
# Dealer wins!
#
# Player's winning stand at 40
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 100
#
# Dealer's Hand:
#  <card hidden>
#   Five of Spades
#
# Player's Hand:
#  King of Clubs
#  Seven of Diamonds
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#   Five of Spades
#
# Player's Hand:
#  King of Clubs
#  Seven of Diamonds
#
# Dealer's Hand:
#  Four of Hearts
#  Five of Spades
#  Seven of Spades
#  Two of Diamonds
# Dealer's Hand =  18
#
# Player's Hand:
#  King of Clubs
#  Seven of Diamonds
# Player's Hand = 17
# Dealer wins!
#
# Player's winning stand at 0
# Would you like to play another hand? Enter 'y' or 'n' n
# Thank you for playing!
